# %% [markdown]
# # Deliverable 1:

# %% [markdown]
# # part 1

# %%
#1 importing the provided data

# %% [raw]
# # btere@DESKTOP-LS0A4L3 MINGW64 ~/osu-bootcamp-assignment/nosql-challenge/Resources (main)

# %% [markdown]
# # $ mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# importing the dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
#Confirm that you created the database and loaded the data properly:
mongo.list_database_names()
# Out:
# ['admin', 'config', 'local', 'met', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
#List the collection(s) in the database to ensure that establishments is there
db.list_collection_names()
# Out:
# ['establishments']

# %%
#Find and display one document in the establishments collection using find_one and display with pprint.
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': '3 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Boodles',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.638929767669,
#  'FHRSID': 1349980,
#  'LocalAuthorityBusinessID': 'PI/000084064',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DH',
#  'RatingDate': '2021-06-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67429acbb0d08945936349d2'),
#  'geocode': {'latitude': '51.150879', 'longitude': '1.378536'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1349980',
#             'rel': 'self'}],
# ...

# %%
#Assign the establishments collection to a variable to prepare the collection for use.
establishments = db['establishments']

# %% [markdown]
# # Part 2: Update the Database

# %% [markdown]
# #1 An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following information to the database:

# %%
# Create a dictionary for the new restaurant data
establishments.insert_one({
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
})
# Out:
# InsertOneResult(ObjectId('67429c15916a0c3c5d6e330a'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
new_restaurant = establishments.find({"BusinessName":"Penang Flavours"})
for i in new_restaurant:
    pprint(i)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67429c15916a0c3c5d6e330a'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [raw]
# # 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {"BusinessType":{"$regex":"Restaurant/Cafe/Canteen"}}
fields ={'BusinessTypeID':1,'BusinessType':1}
results = establishments.find(query,fields)
for r in results:
    pprint(r)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67429acbb0d08945936349d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67429acbb0d08945936349d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67429acbb0d08945936349d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67429acbb0d08945936349d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67429acbb0d08945936349d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67429acbb0d08945936349da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67429acbb0d08945936349dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67429acbb0d08945936349de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...

# %% [markdown]
# #3. Update the new restaurant with the BusinessTypeID you found.

# %%
#Update the new restaurant with the BusinessTypeID you found.
establishments.update_one({"BusinessName":"Penang Flavours"},{"$set":{"BusinessTypeID":1}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
upadated_businesID = establishments.find({"BusinessName":"Penang Flavours"})
for u in upadated_businesID:
    pprint(u)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67429c15916a0c3c5d6e330a'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [raw]
#  4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName':"Dover"}
pprint(f' the total count for Local authorithy name for dover:{establishments.count_documents(query)}')
# Out:
# ' the total count for Local authorithy name for dover:994'

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName':"Dover"})
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
dover_count = {'LocalAuthorityName':'Dover'}
establishments.count_documents(dover_count)
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67429acbb0d0894593634cb4'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
# ...

# %% [raw]
# Some of the number values are stored as strings, when they should be stored as numbers.

# %%
# Use update_many to convert latitude to decimal numbers.
establishments.update_many({},[{'$set':{'geocode.latitude':{'$toDouble':'$geocode.latitude'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Use update_many to convert  longitude to decimal numbers.
establishments.update_many({},[{'$set':{'geocode.longitude':{'$toDouble':'$geocode.longitude'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue

establishments.update_many({}, [{'$set': {'RatingValue': {'$toInt': '$RatingValue'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
query = {}
fields = {'geocode.latitude':1,'geocode.longitude':1,'RatingValue':1}
results = establishments.find(query,fields)
for i in range(5):
    pprint(results[i])
# Out:
# {'RatingValue': 5,
#  '_id': ObjectId('67429acbb0d0894593634cb4'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'RatingValue': 5,
#  '_id': ObjectId('67429acbb0d0894593634cb9'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762}}
# {'RatingValue': 4,
#  '_id': ObjectId('67429acbb0d0894593634cba'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
# {'RatingValue': 4,
#  '_id': ObjectId('67429acbb0d0894593634cbd'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': 5,
#  '_id': ObjectId('67429acbb0d0894593634cbe'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
